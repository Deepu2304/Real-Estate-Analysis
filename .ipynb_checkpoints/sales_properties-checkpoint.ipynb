# %% [markdown]
# # SALES ANALYSIS

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
import os
import calendar

# %%
import os
import pandas as pd


def combine_csv_files(folder_path):
    # Initialize an empty list to store DataFrames
    dfs = []

    # Iterate over each file in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            file_path = os.path.join(folder_path, filename)
            try:
                # Read the CSV file into a DataFrame
                df = pd.read_csv(file_path, engine='python')

                # Append the DataFrame to the list
                dfs.append(df)
            except Exception as e:
                print(f"Error reading file {file_path}: {e}")

    if not dfs:
        print("No valid CSV files found.")
        return

    # Concatenate all DataFrames into a single DataFrame
    combined_df = pd.concat(dfs, ignore_index=True)

    # Write the combined DataFrame to a new CSV file
    combined_df.to_csv("combined_output.csv", index=False)

    print("Combined CSV file saved successfully.")


# Specify the folder path containing the CSV files
folder_path = "/Users/jaideepsai/Desktop/DATA-ANALYTICS/Data Source/extracted-data/RealEstate/sales_properties"

# Combine CSV files
combine_csv_files(folder_path)
# Out:
# Combined CSV file saved successfully.

# %%
sales_path = "combined_output.csv"
sales_data = pd.read_csv(sales_path, delimiter=';')

# %%
sales_data.head()
# Out:
#                                                  Url  Zestimate     Price  \
# 0  https://www.zillow.com/homedetails/8198-Uphill...        NaN  18000000
# 1  https://www.zillow.com/homedetails/4757-Avenid...   223200.0    399990
# 2  https://www.zillow.com/homedetails/61018-Presc...   568947.0    575000
# 3  https://www.zillow.com/homedetails/61875-Anaco...   851656.0    899000
# 4  https://www.zillow.com/homedetails/61879-Petun...        NaN    369900
#
#    Rent Zestimate Days On Zillow  Bathrooms  Bedrooms  Living Area  Lot Size  \
# 0          2435.0  Not specified          4         3         5470       NaN
# 1          1786.0  Not specified          2         3         1056       NaN
# 2          2300.0  Not specified          2         3         1577       NaN
# 3          4798.0  Not specified          2         3         1434       NaN
# 4          1825.0  Not specified          1         3         1040       NaN
#
#        Home Type  ... State Country                      Broker Name  \
# 0  SINGLE_FAMILY  ...    CA     USA                        AKGRE Inc
# 1  SINGLE_FAMILY  ...    CA     USA                  Champion Realty
# 2  SINGLE_FAMILY  ...    CA     USA  BHG Desert Lifestyle Properties
# 3  SINGLE_FAMILY  ...    CA     USA           Cherie Miller & Assoc.
# 4  SINGLE_FAMILY  ...    CA     USA           Cherie Miller & Assoc.
#
#   Has 3D Model  Has Image  Has Video isZillowOwned              sgapt  \
# 0        FALSO  VERDADERO      FALSO         FALSO  For Sale (Broker)
# 1        FALSO  VERDADERO      FALSO         FALSO  For Sale (Broker)
# 2    VERDADERO  VERDADERO  VERDADERO         FALSO  For Sale (Broker)
# 3        FALSO  VERDADERO      FALSO         FALSO  For Sale (Broker)
# 4        FALSO  VERDADERO      FALSO         FALSO  For Sale (Broker)
#
#        statusText statusType,Unnamed: 1
# 0  House for sale             FOR_SALE,
# 1  House for sale             FOR_SALE,
# 2  House for sale             FOR_SALE,
# 3  House for sale             FOR_SALE,
# 4  House for sale             FOR_SALE,
#
# [5 rows x 23 columns]

# %%
sales_data.shape
# Out:
# (350, 23)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Url                    350 non-null    object
#  1   Zestimate              318 non-null    float64
#  2   Price                  350 non-null    int64
#  3   Rent Zestimate         327 non-null    float64
#  4   Days On Zillow         350 non-null    object
#  5   Bathrooms              350 non-null    int64
#  6   Bedrooms               350 non-null    int64
#  7   Living Area            350 non-null    int64
#  8   Lot Size               0 non-null      float64
#  9   Home Type              350 non-null    object
#  10  Street Address         350 non-null    object
#  11  City                   350 non-null    object
#  12  Zip                    350 non-null    int64
#  13  State                  350 non-null    object
#  14  Country                350 non-null    object
#  15  Broker Name            327 non-null    object
#  16  Has 3D Model           350 non-null    object
#  17  Has Image              350 non-null    object
#  18  Has Video              350 non-null    object
#  19  isZillowOwned          350 non-null    object
#  20  sgapt                  350 non-null    object
#  21  statusText             350 non-null    object
#  22  statusType,Unnamed: 1  350 non-null    object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 63.0+ KB

# %%
sales_data.isnull().sum()
# Out:
# Url                        0
# Zestimate                 32
# Price                      0
# Rent Zestimate            23
# Days On Zillow             0
# Bathrooms                  0
# Bedrooms                   0
# Living Area                0
# Lot Size                 350
# Home Type                  0
# Street Address             0
# City                       0
# Zip                        0
# State                      0
# Country                    0
# Broker Name               23
# Has 3D Model               0
# Has Image                  0
# Has Video                  0
# isZillowOwned              0
# sgapt                      0
# statusText                 0
# statusType,Unnamed: 1      0
# dtype: int64

# %%
print(sales_data.columns)
# Out:
# Index(['Url', 'Zestimate', 'Price', 'Rent Zestimate', 'Days On Zillow',
#        'Bathrooms', 'Bedrooms', 'Living Area', 'Lot Size', 'Home Type',
#        'Street Address', 'City', 'Zip', 'State', 'Country', 'Broker Name',
#        'Has 3D Model', 'Has Image', 'Has Video', 'isZillowOwned', 'sgapt',
#        'statusText', 'statusType,Unnamed: 1'],
#       dtype='object')

# %%
sales_data = sales_data.drop(['Days On Zillow', 'Country', 'sgapt', 'Lot Size', 'isZillowOwned'], axis=1)

# %%
sales_data.isnull().sum()
# Out:
# Url                       0
# Zestimate                32
# Price                     0
# Rent Zestimate           23
# Bathrooms                 0
# Bedrooms                  0
# Living Area               0
# Home Type                 0
# Street Address            0
# City                      0
# Zip                       0
# State                     0
# Broker Name              23
# Has 3D Model              0
# Has Image                 0
# Has Video                 0
# statusText                0
# statusType,Unnamed: 1     0
# dtype: int64

# %%
mean_values = sales_data[['Zestimate', 'Rent Zestimate']].mean()
sales_data.loc[:, 'Zestimate'] = sales_data['Zestimate'].fillna(mean_values['Zestimate'])
sales_data.loc[:, 'Rent Zestimate'] = sales_data['Rent Zestimate'].fillna(mean_values['Rent Zestimate'])
sales_data['Broker Name'].fillna("unknown", inplace=True)

# %%
sales_data.isnull().sum()
# Out:
# Url                      0
# Zestimate                0
# Price                    0
# Rent Zestimate           0
# Bathrooms                0
# Bedrooms                 0
# Living Area              0
# Home Type                0
# Street Address           0
# City                     0
# Zip                      0
# State                    0
# Broker Name              0
# Has 3D Model             0
# Has Image                0
# Has Video                0
# statusText               0
# statusType,Unnamed: 1    0
# dtype: int64

# %%
avg_by_zip = sales_data.groupby('Zip')['Price'].mean()

# Plotting the average property price by postal code
plt.figure(figsize=(10, 6))
avg_by_zip.plot(kind='bar', color='teal')
plt.title('Average Property Price by Zip Code')
plt.xlabel('Zip Code')
plt.ylabel('Average Price')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability # Add grid lines on the y-axis
plt.tight_layout()
plt.show()

# %%
amenties = ['Bedrooms', 'Bathrooms', 'Living Area', 'Home Type']
plt.figure(figsize=(12, 10))
for i, amenties in enumerate(amenties, 1):
    plt.subplot(3, 2, i)
    if sales_data[amenties].dtype == 'object':
        sns.countplot(x=amenties, data=sales_data)
        plt.title(f'Distribution of {amenties}')
        plt.xlabel(amenties)
        plt.ylabel('Count')
        
    else:  # For numerical variables
        sns.histplot(x=amenties, data=sales_data, kde=True)
        plt.title(f'Distribution of {amenties}')
        plt.xlabel(amenties)
        plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Zip', hue='statusText', data=sales_data, palette='Set3')
plt.title('Property Status by Postal Code')
plt.xlabel('Postal Code')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.legend(title='Status')
plt.grid(axis='y') 
plt.tight_layout()
plt.show()

# %% [markdown]
# # SALES ANALYSIS WITH POOL

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
import os
import calendar

# %%
import os
import pandas as pd


def combine_csv_files(folder_path):
    # Initialize an empty list to store DataFrames
    dfs = []

    # Iterate over each file in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            file_path = os.path.join(folder_path, filename)
            try:
                # Read the CSV file into a DataFrame
                df = pd.read_csv(file_path, engine='python')

                # Append the DataFrame to the list
                dfs.append(df)
            except Exception as e:
                print(f"Error reading file {file_path}: {e}")

    if not dfs:
        print("No valid CSV files found.")
        return

    # Concatenate all DataFrames into a single DataFrame
    combined_df = pd.concat(dfs, ignore_index=True)

    # Write the combined DataFrame to a new CSV file
    combined_df.to_csv("properties_with_pool.csv", index=False)

    print("Combined CSV file saved successfully.")


# Specify the folder path containing the CSV files
folder_path = "/Users/jaideepsai/Desktop/DATA-ANALYTICS/Data Source/extracted-data/RealEstate/sales_properties_pools"

# Combine CSV files
combine_csv_files(folder_path)
# Out:
# Combined CSV file saved successfully.

# %%
sales_pools_path = "properties_with_pool.csv"
sales_pools_data = pd.read_csv(sales_pools_path, delimiter=';')

# %%
sales_pools_data.head()
# Out:
#                                                  Url  Zestimate    Price  \
# 0  https://www.zillow.com/homedetails/61854-Crest...   392179.0   399000
# 1  https://www.zillow.com/homedetails/4741-Avenid...   753106.0   769000
# 2  https://www.zillow.com/homedetails/63973-Gold-...  1505009.0  1560000
# 3  https://www.zillow.com/homedetails/61880-Valle...   691000.0   691000
# 4  https://www.zillow.com/homedetails/2651-Foxy-F...  1016200.0  1100000
#
#    Rent Zestimate Days On Zillow  Bathrooms  Bedrooms  Living Area  Lot Size  \
# 0          1897.0  Not specified          2         3         1100       NaN
# 1          2901.0  Not specified          3         4         1871       NaN
# 2          1823.0  Not specified          3         3         1538       NaN
# 3          2425.0  Not specified          2         3         1909       NaN
# 4          3211.0  Not specified          2         3         1968       NaN
#
#        Home Type  ... State Country                      Broker Name  \
# 0  SINGLE_FAMILY  ...    CA     USA      REAL BROKERAGE TECHNOLOGIES
# 1  SINGLE_FAMILY  ...    CA     USA                   Backbeat Homes
# 2  SINGLE_FAMILY  ...    CA     USA  BHG Desert Lifestyle Properties
# 3  SINGLE_FAMILY  ...    CA     USA  Berkshire Hathaway HomeServices
# 4  SINGLE_FAMILY  ...    CA     USA                          Compass
#
#   Has 3D Model  Has Image Has Video isZillowOwned              sgapt  \
# 0        FALSO  VERDADERO     FALSO         FALSO  For Sale (Broker)
# 1    VERDADERO  VERDADERO     FALSO         FALSO  For Sale (Broker)
# 2        FALSO  VERDADERO     FALSO         FALSO   New Construction
# 3        FALSO  VERDADERO     FALSO         FALSO  For Sale (Broker)
# 4        FALSO  VERDADERO     FALSO         FALSO  For Sale (Broker)
#
#          statusText statusType,Unnamed: 1
# 0    House for sale             FOR_SALE,
# 1    House for sale             FOR_SALE,
# 2  New construction             FOR_SALE,
# 3    House for sale             FOR_SALE,
# 4    House for sale             FOR_SALE,
#
# [5 rows x 23 columns]

# %%
sales_pools_data['pool']=1

# %%
sales_pools_data.head()
# Out:
#                                                  Url  Zestimate    Price  \
# 0  https://www.zillow.com/homedetails/61854-Crest...   392179.0   399000
# 1  https://www.zillow.com/homedetails/4741-Avenid...   753106.0   769000
# 2  https://www.zillow.com/homedetails/63973-Gold-...  1505009.0  1560000
# 3  https://www.zillow.com/homedetails/61880-Valle...   691000.0   691000
# 4  https://www.zillow.com/homedetails/2651-Foxy-F...  1016200.0  1100000
#
#    Rent Zestimate Days On Zillow  Bathrooms  Bedrooms  Living Area  Lot Size  \
# 0          1897.0  Not specified          2         3         1100       NaN
# 1          2901.0  Not specified          3         4         1871       NaN
# 2          1823.0  Not specified          3         3         1538       NaN
# 3          2425.0  Not specified          2         3         1909       NaN
# 4          3211.0  Not specified          2         3         1968       NaN
#
#        Home Type  ... Country                      Broker Name  Has 3D Model  \
# 0  SINGLE_FAMILY  ...     USA      REAL BROKERAGE TECHNOLOGIES         FALSO
# 1  SINGLE_FAMILY  ...     USA                   Backbeat Homes     VERDADERO
# 2  SINGLE_FAMILY  ...     USA  BHG Desert Lifestyle Properties         FALSO
# 3  SINGLE_FAMILY  ...     USA  Berkshire Hathaway HomeServices         FALSO
# 4  SINGLE_FAMILY  ...     USA                          Compass         FALSO
#
#    Has Image Has Video isZillowOwned              sgapt        statusText  \
# 0  VERDADERO     FALSO         FALSO  For Sale (Broker)    House for sale
# 1  VERDADERO     FALSO         FALSO  For Sale (Broker)    House for sale
# 2  VERDADERO     FALSO         FALSO   New Construction  New construction
# 3  VERDADERO     FALSO         FALSO  For Sale (Broker)    House for sale
# 4  VERDADERO     FALSO         FALSO  For Sale (Broker)    House for sale
#
#   statusType,Unnamed: 1 pool
# 0             FOR_SALE,    1
# 1             FOR_SALE,    1
# 2             FOR_SALE,    1
# 3             FOR_SALE,    1
# 4             FOR_SALE,    1
#
# [5 rows x 24 columns]

# %%
sns.countplot(x=pool, data=sales_pools_data)
plt.title(f'Distribution of {pool}')
plt.xlabel('pool')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 sns.countplot(x=pool, data=sales_pools_data)
#       2 plt.title(f'Distribution of {pool}')
#       3 plt.xlabel('pool')
#
# NameError: name 'pool' is not defined

# %%
all_zips = sales_pools_data['Zip'].unique()
pool_properties = sales_pools_data[sales_pools_data['pool'] == 1]
plt.figure(figsize=(10, 6))
sns.countplot(x='Zip', data=sales_pools_data, order=all_zips, palette='Reds')
plt.title('Number of Properties with a Pool by Zip Code')
plt.xlabel('Zip Code')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')  # Add grid lines on the y-axis
plt.tight_layout()
plt.show()
